# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_md")

# Process whole documents
text = ('''War and Peace broadly focuses on Napoleon’s invasion
         of Russia in 1812 and follows three of the most well-known
         characters in literature: Pierre Bezukhov, the illegitimate
         son of a count who is fighting for his inheritance and
         yearning for spiritual fulfillment; Prince Andrei Bolkonsky,
         who leaves his family behind to fight in the war against Napoleon;
         and Natasha Rostov, the beautiful young daughter of a nobleman who
         intrigues both men.''')
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['War', 'Peace', 'Napoleon’s invasion', 'Russia', 'the most well-known\n         characters', 'literature', 'Pierre Bezukhov', 'the illegitimate\n         son', 'a count', 'who', 'his inheritance', 'spiritual fulfillment', 'Prince Andrei Bolkonsky', 'who', 'his family', 'the war', 'Napoleon', 'Natasha Rostov', 'the beautiful young daughter', 'a nobleman', 'who', 'both men']
# Verbs: ['focus', 'follow', 'know', 'fight', 'yearn', 'leave', 'fight', 'intrigue']
# Napoleon ORG
# Russia GPE
# 1812 DATE
# three CARDINAL
# Pierre Bezukhov PERSON
# Andrei Bolkonsky PERSON
# Napoleon PERSON
# Natasha Rostov PERSON

# %%
from spacy import displacy

displacy.render(doc, style="dep")

# In[3]:
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="00abd29d4692493db18b2d707573498d-0" class="displacy" width="13875" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">War</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
# ...
